# %%
import urllib.request, urllib.parse, urllib.error
from bs4 import BeautifulSoup
import ssl 
import requests
import numpy as np

ctx = ssl.create_default_context()
ctx.check_hostname = False 
ctx.verify_mode = ssl.CERT_NONE

headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.77 Safari/537.36'}

# %%
import urllib.request, urllib.parse, urllib.error
from bs4 import BeautifulSoup
import ssl 
import requests
import numpy as np
ctx = ssl.create_default_context()
ctx.check_hostname = False 
ctx.verify_mode = ssl.CERT_NONE
        
movie_links = []
detail_links = []

headers = {'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 11_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.93 Safari/537.36'}
movie_names = []
for i in range(5):
    url = 'https://www.metacritic.com/browse/movies/score/metascore/all/filtered?sort=desc&page='+ str(i)
    page = requests.get(url, headers = headers)
    soup = BeautifulSoup(page.content, "html.parser")
    tds = soup.find_all('td', class_ = 'clamp-summary-wrap')
    for td in tds:
        movie_name = td.find('h3').text
        movie_names.append(movie_name)
        link = td.find('a', class_ = 'title').get('href', None)
        movie_link = 'https://www.metacritic.com' + link + '/details'
        movie_tup = (movie_link, movie_name)
        movie_links.append(movie_tup)

def get_people(soup, movie_name, summary_type): 
    person = soup.find('td', class_ = 'person')
    person_sn = movie_name + "'s " + summary_type + " Credits"
    if movie_name[-1].lower() == 's':
        person_sn = movie_name + "' " + summary_type + " Credits"
    person_table = soup.find('table', class_ = 'credits', summary = person_sn)
    if person_table == None:
        return []
    person_names = [a.text.strip() for a in person_table.find_all('a')]
    return person_names

cd_dict = {}

for mli, movie_name in movie_links:
    page = requests.get(mli, headers = headers)
    soup = BeautifulSoup(page.content, "html.parser")
    director_names = get_people(soup, movie_name, "Director")
    cast_names = get_people(soup, movie_name, "Cast")
    for d in director_names:
        if cd_dict.get(d) == None:
            cd_dict[d] = {}
        for c in cast_names:
            if cd_dict[d].get(c) == None:
                cd_dict[d][c] = 0
            cd_dict[d][c]+=1
print(cd_dict)
# Out:
# {'Orson Welles': {'Agnes Moorehead': 1, 'Dorothy Comingore': 1, 'Erskine Sanford': 1, 'Everett Sloane': 1, 'Fortunio Bonanova': 1, 'George Coulouris': 1, 'Georgia Backus': 2, 'Gus Schilling': 1, 'Harry Shannon': 1, 'Paul Stewart': 1, 'Philip Van Zandt': 1, 'Ray Collins': 1, 'Ruth Warrick': 1, 'William Alland': 1, 'Joi Lansing': 1, 'Lalo Rios': 1, 'Michael Sargent': 1, 'Phil Harvey': 1, 'Victor Millan': 1, 'Alan Webb': 1, 'Fernando Rey': 1, 'Jeremy Rowe': 1, 'Keith Baxter': 1, 'Keith Pyott': 1, 'Harry A. Bailey': 1, 'Jack Baxley': 1, 'Olive Ball': 1, 'William Blees': 1, 'Alexander Welles': 1, 'Gary Graver': 1, 'Howard Hughes': 1, 'Joseph Cotten': 1, 'Richard Drewett': 1}, 'Francis Ford Coppola': {'Abe Vigoda': 1, 'Al Lettieri': 1, 'Diane Keaton': 1, 'Gianni Russo': 1, 'James Caan': 1, 'John Cazale': 2, 'John Marley': 1, 'Richard Conte': 1, 'Richard S. Castellano': 1, 'Robert Duvall': 3, 'Rudy Bond': 1, 'Sterling Hayden': 1, 'Talia Shire': 2, 'Albert Hall': 2, 'Bo Byers': 2, 'Dennis Ho
# ...

# %%
import urllib.request, urllib.parse, urllib.error
from bs4 import BeautifulSoup
import ssl 
import requests
import numpy as np
ctx = ssl.create_default_context()
ctx.check_hostname = False 
ctx.verify_mode = ssl.CERT_NONE
        
movie_links = []
detail_links = []

headers = {'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 11_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.93 Safari/537.36'}
movie_names = []
tup_names = ()
for i in range(5):
    url = 'https://www.metacritic.com/browse/movies/score/metascore/all/filtered?sort=desc&page='+ str(i)
    page = requests.get(url, headers = headers)
    soup = BeautifulSoup(page.content, "html.parser")
    tds = soup.find_all('td', class_ = 'clamp-summary-wrap')
    for td in tds:
        movie_name = td.find('h3').text
        movie_names.append(movie_name)
        link = td.find('a', class_ = 'title').get('href', None)
        movie_link = 'https://www.metacritic.com' + link + '/details'
        movie_tup = (movie_link, movie_name)
        tup_names = tup_names + movie_tup
        movie_links.append(movie_tup)
#tried nesting this 
def get_people(soup, movie_name, summary_type): 
    person = soup.find('td', class_ = 'person')
    person_sn = movie_name + "'s " + summary_type + " Credits"
    if movie_name[-1].lower() == 's':
        person_sn = movie_name + "' " + summary_type + " Credits"
    person_table = soup.find('table', class_ = 'credits', summary = person_sn)
    if person_table == None:
        return []
    person_names = [a.text.strip() for a in person_table.find_all('a')]
    return person_names

cd_dict = {}

for mli, movie_name in movie_links:
    page = requests.get(mli, headers = headers)
    soup = BeautifulSoup(page.content, "html.parser")
    director_names = get_people(soup, movie_name, "Director")
    cast_names = get_people(soup, movie_name, "Cast")
    for d in director_names:
        if cd_dict.get(d) == None:
            cd_dict[d] = {}
        for c in cast_names:
            if cd_dict[d].get(c) == None:
                cd_dict[d][c] = 0
            cd_dict[d][c]+=1
print(cd_dict)
# Out:
# {'Orson Welles': {'Agnes Moorehead': 1, 'Dorothy Comingore': 1, 'Erskine Sanford': 1, 'Everett Sloane': 1, 'Fortunio Bonanova': 1, 'George Coulouris': 1, 'Georgia Backus': 2, 'Gus Schilling': 1, 'Harry Shannon': 1, 'Paul Stewart': 1, 'Philip Van Zandt': 1, 'Ray Collins': 1, 'Ruth Warrick': 1, 'William Alland': 1, 'Joi Lansing': 1, 'Lalo Rios': 1, 'Michael Sargent': 1, 'Phil Harvey': 1, 'Victor Millan': 1, 'Alan Webb': 1, 'Fernando Rey': 1, 'Jeremy Rowe': 1, 'Keith Baxter': 1, 'Keith Pyott': 1, 'Harry A. Bailey': 1, 'Jack Baxley': 1, 'Olive Ball': 1, 'William Blees': 1, 'Alexander Welles': 1, 'Gary Graver': 1, 'Howard Hughes': 1, 'Joseph Cotten': 1, 'Richard Drewett': 1}, 'Francis Ford Coppola': {'Abe Vigoda': 1, 'Al Lettieri': 1, 'Diane Keaton': 1, 'Gianni Russo': 1, 'James Caan': 1, 'John Cazale': 2, 'John Marley': 1, 'Richard Conte': 1, 'Richard S. Castellano': 1, 'Robert Duvall': 3, 'Rudy Bond': 1, 'Sterling Hayden': 1, 'Talia Shire': 2, 'Albert Hall': 2, 'Bo Byers': 2, 'Dennis Ho
# ...

# %%
a1 = input('please input an actor/actress ')
a2 = input('please input an actor/actress ')
a3 = input('please input an actor/actress ')
a4 = input('please input an actor/actress ')
a5 = input('please input an actor/actress ')
#these lists are names with lower case L's not ones
l1 = []
l2 = []
l3 = []
l4 = []
l5 = []

actd = {} 
#when inputting a name, please copy and past from the list above, names with special pronunciation characters
#will result in no values for that actors key unless typed explicitly as they appear

for mli, movie_name in movie_links:
    page = requests.get(mli, headers = headers)
    soup = BeautifulSoup(page.content, "html.parser")
    cast_names = get_people(soup, movie_name, "Cast")
    if a1 in cast_names:
        l1.extend(cast_names)
    
    if a2 in cast_names:
        l2.extend(cast_names)
    
    if a3 in cast_names:
        l3.extend(cast_names)
    
    if a4 in cast_names:
        l4.extend(cast_names)
    
    if a5 in cast_names:
        l5.extend(cast_names)
        
actd[a1] = l1        
actd[a2] = l2        
actd[a3] = l3        
actd[a4] = l4        
actd[a5] = l5

print(actd)
# Out:
# please input an actor/actress Edson Jean
# please input an actor/actress Meryl Streep
# please input an actor/actress Alex Jennings
# please input an actor/actress Alia Janine
# please input an actor/actress Dore Davidson
# ...

# %%
director1 = input('please enter your favorite director ')
director2 = input('please enter director two ')


#i did some parts of this a little differently from you but the rest of it is exactly from the IPYNB on canvas
#i ended up changing sub_dic1 and 2 to sub_dict1 and 2, this is just because I wrote it that way in the first line of code
#and didn't want to change it. I used .items() on cd_dict instead of on the iteration variable, just because the
#other method kept throwing up error. cd_dict is basically the same thing as all_movies in your the canvas document
#I also used .get() instead of simply adding the value iteration variable
for ik, iv in cd_dict.items():
    for k in ik:
        if director1 == ik:
            sub_dict1 = cd_dict.get(ik)


for ik, iv in cd_dict.items():
    for k in ik:
        if director2 == ik:
            sub_dict2 = cd_dict.get(ik)

sub_actor1 = list(sub_dict1.keys())
sub_actor2 = list(sub_dict2.keys())


set_actor1 = set(sub_actor1)
set_actor2 = set(sub_actor2)
combine_set = set_actor1.union(set_actor2)

print(combine_set)            

dir1_actor = dict()
for i in combine_set:
    dir1_actor[i] = 0


dir2_actor = dict()
for i in combine_set:
    dir2_actor[i] = 0


for key, value in dir1_actor.items():
    for k, v in sub_dict1.items():
        if key == k:
            dir1_actor[key] = v


for key, value in dir2_actor.items():
    for k, v in sub_dict2.items():
        if key == k:
            dir2_actor[key] = v


dir1_vector = list(dir1_actor.values())
dir2_vector = list(dir2_actor.values())


divident = 0 
for i in range(len(dir1_vector)):
    summing = dir1_vector[i] * dir2_vector[i]
    divident = divident + summing
print(divident)

a = 0
b = 0
for i in range(len(dir1_vector)):
    sum1 = (dir1_vector[i])**2
    a = a + sum1
    sum2 = (dir2_vector[i])**2
    b = b + sum2
divisor = (a**0.5)*(b**0.5)
print(divisor)

cosine_similarity = divident/divisor
print(cosine_similarity)
# Out:
# please enter your favorite director Orson Welles
# please enter director two Alfred Hitchcock
# ...

# %%
print(movie_names)
# Out:
# ['Citizen Kane', 'The Godfather', 'Rear Window', 'Casablanca', 'Boyhood', 'Three Colors: Red', 'Vertigo', 'Notorious', "Singin' in the Rain", 'City Lights', 'Moonlight', 'Intolerance', 'Pinocchio', 'Touch of Evil', 'The Lady Vanishes', 'The Treasure of the Sierra Madre', "Pan's Labyrinth", 'Some Like It Hot', 'North by Northwest', 'Hoop Dreams', 'Rashomon', 'All About Eve', 'Jules and Jim', 'The Wild Bunch', 'My Left Foot', 'The Third Man', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb', 'Quo Vadis, Aida?', 'Gone with the Wind', '4 Months, 3 Weeks and 2 Days', 'Psycho', 'Battleship Potemkin', 'A Streetcar Named Desire', 'American Graffiti', 'Dumbo', 'Roma', 'Ran', 'The Shop Around the Corner', '12 Angry Men', 'Manchester by the Sea', "Rosemary's Baby", 'The Maltese Falcon', '12 Years a Slave', 'Killer of Sheep', 'Nashville', 'Ratatouille', 'Parasite', 'Rocks', "Don't Look Now", 'The Grapes of Wrath', 'Children of Paradise (1945)', 'Mean Streets', 'The Lady Eve
# ...
